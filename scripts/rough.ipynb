# %%
# create_mapping.py
import pandas as pd

proteins = [
    ("INHA_MYCTU",  "InhA/InhA_alignment_fixed.a2m",  0.2),
    ("KATG_MYCTU",  "KatG/KatG_alignment_fixed.a2m",  0.2),
    ("DPRE1_MYCTU", "DprE1/DprE1_alignment_fixed.a2m", 0.2),
    ("EMBB_MYCTU",  "EmbB/EmbB_alignment_fixed.a2m",  0.2),
    ("MMPL3_MYCTU", "MmpL3/MmpL3_alignment_fixed.a2m", 0.2),
    ("ATPE_MYCTU",  "AtpE/AtpE_alignment_fixed.a2m",  0.2),
    ("RPOB_MYCTU",  "RpoB/RpoB_alignment_fixed.a2m",  0.2),
]

df = pd.DataFrame(proteins, columns=["protein_name", "msa_location", "theta"])
df.to_csv("data/mappings/TB_proteins_mapping.csv", index=False)
print(df)
